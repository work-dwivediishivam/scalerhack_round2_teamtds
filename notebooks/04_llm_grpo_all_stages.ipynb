# %% [markdown]
# # Runway Zero: All-Stage LLM GRPO
#
# This notebook runs the actual TRL/GRPO training path. It should be executed in a GPU runtime.

# %%
# !pip install -e .
# !pip install -r requirements-training.txt

# %%
# !python scripts/train_llm_grpo_all_stages.py \
  --model Qwen/Qwen2.5-Coder-7B-Instruct \
  --stages 1 2 3 \
  --max-steps 60 \
  --output-dir results/llm_runs/qwen25_runway_zero

# %%
# !python scripts/run_hf_model_rollouts.py --model qwen-coder --stage 1 --max-steps 8
