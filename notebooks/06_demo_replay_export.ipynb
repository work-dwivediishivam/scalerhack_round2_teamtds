# %% [markdown]
# # Demo Replay Export
#
# Export the exact environment traces consumed by the website replay UI.

# %%
# %pip install -e ..

# %%
# !python ../scripts/export_demo_trace.py
# !mkdir -p ../web/public/traces
# !cp ../results/traces/*.json ../web/public/traces/
