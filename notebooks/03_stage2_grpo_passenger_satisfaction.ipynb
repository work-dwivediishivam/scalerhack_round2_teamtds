# %% [markdown]
# # Stage 2 GRPO: Passenger Satisfaction
#
# This notebook entrypoint trains/evaluates Runway Zero level 2, where the reward adds passenger satisfaction, missed connections, emergency handling, and stranded-passenger penalties.

# %%
# %pip install -r ../requirements-training.txt
# %pip install -e ..

# %%
# !python ../scripts/train_llm_grpo_all_stages.py --stages 2 --seed-count 4 --warmup-horizon 10 --max-steps 80 --num-generations 4 --batch-size 1 --grad-accum 4 --output-dir ../results/llm_runs/stage2_passenger_grpo
