# %% [markdown]
# # Model Comparison
#
# Compare base planners and trained Runway Zero controllers across the four hackathon model slots.

# %%
# %pip install -r ../requirements-training.txt
# %pip install -e ..

# %%
# !python ../scripts/run_hf_model_rollouts.py --model qwen-coder --stage 1 --max-steps 12
# !python ../scripts/evaluate_baselines.py
# !python ../scripts/make_plots.py
