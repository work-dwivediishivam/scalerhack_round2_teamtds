# %% [markdown]
# # Runway Zero Smoke Test
#
# Validates `reset`, `step`, `state`, reward components, and baseline rollouts.

# %%
# !pip install -e .
from runway_zero import RunwayZeroEnv
env = RunwayZeroEnv(stage=1, seed=7)
obs = env.reset(stage=1, seed=7)
obs.keys(), obs['clock']

# %%
for _ in range(8):
    result = env.step([])
print(env.observation()['pending_decisions'][:3])
print(result.info['reward_breakdown'])
