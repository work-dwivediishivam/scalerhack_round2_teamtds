# %% [markdown]
# # Baseline Heuristics
#
# Runs random, FIFO, and recovery policies across the three stages.

# %%
# !pip install -e .
# !python scripts/evaluate_baselines.py
# !python scripts/make_plots.py

# %%
import json, pandas as pd
rows = json.load(open('results/baseline_metrics.json'))
pd.DataFrame(rows).groupby(['stage', 'policy']).mean(numeric_only=True)
