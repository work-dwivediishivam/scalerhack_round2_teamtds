# %% [markdown]
# # Stage 3 GRPO: Multi-Agent Economics
#
# This is the final-boss training entrypoint: 10 Indian airports, IndiGo/Air India/Akasa Air/SpiceJet agents, slot negotiation, compensation, fuel delay, fairness, passenger satisfaction, and airline cash.

# %%
# %pip install -r ../requirements-training.txt
# %pip install -e ..

# %%
# !python ../scripts/train_llm_grpo_all_stages.py --stages 3 --seed-count 4 --warmup-horizon 12 --max-steps 120 --num-generations 4 --batch-size 1 --grad-accum 4 --output-dir ../results/llm_runs/stage3_economics_grpo
